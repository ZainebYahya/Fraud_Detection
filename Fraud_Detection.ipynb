# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
credit_card = pd.read_csv('creditcard.csv')

# %%
credit_card.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
# explore the statisticals info of numeric data
credit_card.describe().T
# Out:
#            count     mean      std     min      25%      50%       75%  \
# Time   284807.00 94813.86 47488.15    0.00 54201.50 84692.00 139320.50
# V1     284807.00     0.00     1.96  -56.41    -0.92     0.02      1.32
# V2     284807.00     0.00     1.65  -72.72    -0.60     0.07      0.80
# V3     284807.00    -0.00     1.52  -48.33    -0.89     0.18      1.03
# V4     284807.00     0.00     1.42   -5.68    -0.85    -0.02      0.74
# V5     284807.00    -0.00     1.38 -113.74    -0.69    -0.05      0.61
# V6     284807.00     0.00     1.33  -26.16    -0.77    -0.27      0.40
# V7     284807.00    -0.00     1.24  -43.56    -0.55     0.04      0.57
# V8     284807.00    -0.00     1.19  -73.22    -0.21     0.02      0.33
# V9     284807.00    -0.00     1.10  -13.43    -0.64    -0.05      0.60
# V10    284807.00     0.00     1.09  -24.59    -0.54    -0.09      0.45
# V11    284807.00     0.00     1.02   -4.80    -0.76    -0.03      0.74
# ...

# %%
# checking null values
credit_card.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
fraud = credit_card[credit_card['Class'] ==1]
non_fraud = credit_card[credit_card['Class'] ==0]

# %%
# let's do some comparisons between the amount of the transactions in the different classes 
pd.concat([fraud.Amount.describe(), non_fraud.Amount.describe()],axis=1)
# Out:
#        Amount    Amount
# count  492.00 284315.00
# mean   122.21     88.29
# std    256.68    250.11
# min      0.00      0.00
# 25%      1.00      5.65
# 50%      9.25     22.00
# 75%    105.89     77.05
# max   2125.87  25691.16

# %%
# let's do some comparisons between the time of the transaction in the different classes 
pd.concat([fraud.Time.describe(), non_fraud.Time.describe()],axis=1)
# Out:
#            Time      Time
# count    492.00 284315.00
# mean   80746.81  94838.20
# std    47835.37  47484.02
# min      406.00      0.00
# 25%    41241.50  54230.00
# 50%    75568.50  84711.00
# 75%   128483.00 139333.00
# max   170348.00 172792.00

# %%
# will use  datetime.timedelta() to convert seconds to hours and minutes so it will be easier to read
time_delta = pd.to_timedelta(credit_card['Time'], unit= 's')
credit_card['minuts'] = (time_delta.dt.components.minutes).astype(int)
credit_card['hours'] = (time_delta.dt.components.hours).astype(int)

# %%
sns.countplot(credit_card[credit_card['Class']==1]['hours']).set_title('Distribution of fraud transactions ')
# Out:
# Text(0.5, 1.0, 'Distribution of fraud transactions ')

# %%
sns.countplot(credit_card[credit_card['Class']==0]['hours']).set_title('Distribution of non_fraud transactions ')
# Out:
# Text(0.5, 1.0, 'Distribution of non_fraud transactions ')

# %%
credit_card.hist(bins = 50, figsize = (30,25))
# Out:
# array([[<AxesSubplot:title={'center':'Time'}>,
#         <AxesSubplot:title={'center':'V1'}>,
#         <AxesSubplot:title={'center':'V2'}>,
#         <AxesSubplot:title={'center':'V3'}>,
#         <AxesSubplot:title={'center':'V4'}>,
#         <AxesSubplot:title={'center':'V5'}>],
#        [<AxesSubplot:title={'center':'V6'}>,
#         <AxesSubplot:title={'center':'V7'}>,
#         <AxesSubplot:title={'center':'V8'}>,
#         <AxesSubplot:title={'center':'V9'}>,
#         <AxesSubplot:title={'center':'V10'}>,
#         <AxesSubplot:title={'center':'V11'}>],
#        [<AxesSubplot:title={'center':'V12'}>,
#         <AxesSubplot:title={'center':'V13'}>,
#         <AxesSubplot:title={'center':'V14'}>,
#         <AxesSubplot:title={'center':'V15'}>,
#         <AxesSubplot:title={'center':'V16'}>,
#         <AxesSubplot:title={'center':'V17'}>],
#        [<AxesSubplot:title={'center':'V18'}>,
#         <AxesSubplot:title={'center':'V19'}>,
# ...

# %%
# find the correlation between the class and the other features 
credit_card.corr()['Class'].sort_values(ascending=False)
# Out:
# Class     1.00
# V11       0.15
# V4        0.13
# V2        0.09
# V21       0.04
# V19       0.03
# V20       0.02
# V8        0.02
# V27       0.02
# V28       0.01
# Amount    0.01
# V26       0.00
# V25       0.00
# V22       0.00
# minuts   -0.00
# V23      -0.00
# V15      -0.00
# V13      -0.00
# V24      -0.01
# Time     -0.01
# hours    -0.02
# V6       -0.04
# V5       -0.09
# V9       -0.10
# V1       -0.10
# V18      -0.11
# V7       -0.19
# V3       -0.19
# V16      -0.20
# V10      -0.22
# V12      -0.26
# V14      -0.30
# V17      -0.33
# Name: Class, dtype: float64

# %%
# get the features and visualizing them with nonfraud
fig,axs=plt.subplots(12,3,figsize = (30,60))
for i,ax in zip(credit_card.columns,axs.flatten()):
    sns.boxenplot(x=credit_card['Class'], y=i, data=credit_card, ax= ax)

# %%
sns.countplot(credit_card['Class']).set_xticklabels(['Not Fraud', 'Fraud'])
# Out:
# [Text(0, 0, 'Not Fraud'), Text(1, 0, 'Fraud')]

# %%
# we can clearly see that the data is highly unbalanced we will use RandomUnderSampling
from imblearn.under_sampling import RandomUnderSampler 
under_sample = RandomUnderSampler(sampling_strategy= 0.5)

# %%
X = credit_card.copy()
X = X.drop(['Class'],1)

# %%
y = credit_card['Class'].values.reshape(-1,1)

# %%
y.shape
# Out:
# (284807, 1)

# %%
X.shape
# Out:
# (284807, 32)

# %%
X_under , y_under = under_sample.fit_resample(X,y)

# %%
Y = pd.DataFrame(y_under, columns= ['Class'])

# %%
sns.countplot(Y['Class']).set_xticklabels(['Not Fraud', 'Fraud'])
# Out:
# [Text(0, 0, 'Not Fraud'), Text(1, 0, 'Fraud')]

# %%
# big improvment as we see above 
# now split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_under,y_under, test_size = 0.2, random_state = 1)

# %%
# now let's predict credit cards frauds with Logistic Regression
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression(random_state=2)
logit  = model1.fit(X_train,y_train)
y_predict_logit = model1.predict(X_test)

# %%
# let's check the scores
from sklearn import metrics
accuracy_logit = metrics.accuracy_score(y_test, y_predict_logit)
accuracy_logit
# Out:
# 0.9391891891891891

# %%
preciesion_logit = metrics.precision_score(y_test, y_predict_logit)
preciesion_logit
# Out:
# 0.9891304347826086

# %%
recall_logit = metrics.recall_score(y_test, y_predict_logit)
recall_logit
# Out:
# 0.8425925925925926

# %%
f1_logit = metrics.f1_score(y_test, y_predict_logit)
f1_logit
# Out:
# 0.91

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict_logit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       188
#            1       0.99      0.84      0.91       108
#
#     accuracy                           0.94       296
#    macro avg       0.95      0.92      0.93       296
# weighted avg       0.94      0.94      0.94       296

# %%
# let's try random forest 
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier()
rf = model2.fit(X_train, y_train)
y_predict_rf= model2.predict(X_test)

# %%
accuracy_rf = metrics.accuracy_score(y_test, y_predict_rf)
accuracy_rf
# Out:
# 0.9527027027027027

# %%
preciesion_rf = metrics.precision_score(y_test, y_predict_rf)
preciesion_rf
# Out:
# 0.9895833333333334

# %%
recall_rf = metrics.recall_score(y_test, y_predict_rf)
recall_rf
# Out:
# 0.8796296296296297

# %%
f1_rf = metrics.f1_score(y_test, y_predict_rf)
f1_rf
# Out:
# 0.9313725490196079

# %%
print(classification_report(y_test, y_predict_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       188
#            1       0.99      0.88      0.93       108
#
#     accuracy                           0.95       296
#    macro avg       0.96      0.94      0.95       296
# weighted avg       0.95      0.95      0.95       296
